# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import json
from pprint import pprint
from config import api_key
from citipy import citipy

# %% [markdown]
# # Generate Random City Data

# %%
output_data_file = "output/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 609

# %%
print(cities)
# Out:
# ['port lincoln', 'souillac', 'illoqqortoormiut', 'port alfred', 'ribeira grande', 'dunedin', 'tuktoyaktuk', 'ushuaia', 'banda aceh', 'kirakira', 'thompson', 'shchelyayur', 'taolanaro', 'hobart', 'carutapera', 'clyde river', 'vestmanna', 'taburi', 'buckeye', 'albany', 'north bend', 'namatanai', 'aswan', 'road town', 'esperance', 'hilo', 'savelugu', 'saint-philippe', 'rikitea', 'usak', 'waiouru', 'olafsvik', 'saint joseph', 'norman wells', 'filipesti', 'darhan', 'mpika', 'butaritari', 'bereda', 'dekoa', 'chumikan', 'carnarvon', 'jamestown', 'mar del plata', 'chifeng', 'chuy', 'lebu', 'provideniya', 'padang', 'georgetown', 'longyearbyen', 'ancud', 'varhaug', 'malino', 'cabedelo', 'saldanha', 'mataura', 'hermanus', 'atuona', 'avarua', 'saint-pierre', 'takoradi', 'vesyegonsk', 'muhororo', 'takhtamygda', 'igurubi', 'caravelas', 'castro', 'busselton', 'kodiak', 'kapaa', 'lagoa', 'rupnagar', 'comodoro rivadavia', 'arraial do cabo', 'vestmannaeyjar', 'beverly hills', 'saint george', 'nileshwar', 'bongandanga', 'norilsk', 'port elizabeth', 'prince rupert', 'dingle', 'benguela', 'bowen', 'zhigansk', 'cape town', 'talnakh', 'san carlos del zulia', 'qaqortoq', 'barentsburg', 'tsihombe', 'malpe', 'santa fe', 'saskylakh', 'samarai', 'bluff', 'vao', 'leningradskiy', 'puerto ayora', 'cutro', 'byron bay', 'kearney', 'sistranda', 'vostok', 'east london', 'new norfolk', 'salinas', 'pevek', 'nguru', 'ranong', 'nhulunbuy', 'chokwe', 'nikolskoye', 'sumbawa', 'qaanaaq', 'klaksvik', 'punta arenas', 'qandala', 'pochutla', 'kaohsiung', 'kondoa', 'vaini', 'khorinsk', 'nome', 'belushya guba', 'vuktyl', 'amderma', 'saint-andre', 'mys shmidta', 'thilogne', 'muyezerskiy', 'khatanga', 'vaitupu', 'hasaki', 'santa rosa', 'gigmoto', 'katsuura', 'tiksi', 'barrow', 'cubara', 'chirongui', 'luderitz', 'grindavik', 'prainha', 'coahuayana', 'bredasdorp', 'ponta do sol', 'grand river south east', 'bethel', 'teahupoo', 'geraldton', 'leczna', 'juegang', 'severo-kurilsk', 'kavieng', 'cidreira', 'hirara', 'sarankhola', 'assiniboia', 'mahadday weyne', 'shihezi', 'sorong', 'grand gaube', 'rawson', 'nabire', 'carballo', 'canavieiras', 'ola', 'dolores', 'diebougou', 'dornoch', 'boa vista', 'palabuhanratu', 'kysyl-syr', 'fukue', 'torbay', 'coquimbo', 'senneterre', 'jijiga', 'hofn', 'rocha', 'tabiauea', 'sao joao de pirabas', 'bay saint louis', 'kalabo', 'muroto', 'buraydah', 'sorgun', 'giyani', 'labuhan', 'kruisfontein', 'chokurdakh', 'bakersfield', 'manta', 'xichang', 'isangel', 'cabatuan', 'filingue', 'aklavik', 'skalistyy', 'gimli', 'ponta delgada', 'houma', 'methoni', 'vila velha', 'osvaldo cruz', 'lata', 'nanlong', 'chesterton', 'mackay', 'bayan', 'sentyabrskiy', 'pincher creek', 'half moon bay', 'aquiraz', 'nemuro', 'coulihaut', 'sisimiut', 'belyy yar', 'villamontes', 'nishihara', 'dwarka', 'cape coast', 'oudtshoorn', 'paradwip', 'taihe', 'grafton', 'berlevag', 'chhindwara', 'ahipara', 'araceli', 'biggar', 'iralaya', 'hambantota', 'port moresby', 'porto walter', 'starychi', 'yellowknife', 'ixtapa', 'shaunavon', 'fortuna', 'tigil', 'axim', 'samusu', 'broome', 'buariki', 'alotau', 'gunnedah', 'makakilo city', 'beringovskiy', 'iqaluit', 'tarudant', 'kamenka', 'reynosa', 'kaitangata', 'tumannyy', 'nisia floresta', 'jega', 'kozmodemyansk', 'mudyuga', 'carauari', 'sinnamary', 'virginia beach', 'portland', 'dubai', 'meulaboh', 'kazalinsk', 'meyungs', 'fort nelson', 'najran', 'hithadhoo', 'pisco', 'paamiut', 'tomatlan', 'honiara', 'anadyr', 'arlit', 'maracas', 'petropavlovsk-kamchatskiy', 'nizhniy odes', 'hollins', 'asau', 'hualmay', 'jacobina', 'aksu', 'boguchany', 'victoria', 'kibuye', 'lieksa', 'laurinburg', 'puerto escondido', 'airai', 'tautira', 'lolua', 'cabo san lucas', 'rio cuarto', 'perafita', 'waipawa', 'bintulu', 'louisbourg', 'cockburn town', 'lasa', 'redhakhol', 'patea', 'springbok', 'bismil', 'vanavara', 'broken hill', 'umm kaddadah', 'nioro', 'attawapiskat', 'marsh harbour', 'pimenta bueno', 'honningsvag', 'namibe', 'alofi', 'tasiilaq', 'dikson', 'belaya gora', 'qo ...

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Houston"

# Build query URL
query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"

# %%
print(api_key)
# Out:
# 4d3ba79f30fc7971ee60f75a94c826c2

# %% [markdown]
# # API Calls

# %%
x=0
y=1

# %%
for city in cities:
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    city = cities[x]
    x+=1
    target_url = f"{base_url}&q={city}&appid={api_key}"
    try:
        response=requests.get(target_url).json()
        response
        if x==51:
            y+=1
            x=1
        print(f"Processing Record {x} of Set {y}, {city}")
    except MissingSchema: 
        print("city not found. Skipping...")
# Out:
# Processing Record 1 of Set 1, port lincoln
# Processing Record 2 of Set 1, souillac
# Processing Record 3 of Set 1, illoqqortoormiut
# Processing Record 4 of Set 1, port alfred
# Processing Record 5 of Set 1, ribeira grande
# Processing Record 6 of Set 1, dunedin
# Processing Record 7 of Set 1, tuktoyaktuk
# Processing Record 8 of Set 1, ushuaia
# Processing Record 9 of Set 1, banda aceh
# Processing Record 10 of Set 1, kirakira
# Processing Record 11 of Set 1, thompson
# Processing Record 12 of Set 1, shchelyayur
# Processing Record 13 of Set 1, taolanaro
# Processing Record 14 of Set 1, hobart
# Processing Record 15 of Set 1, carutapera
# Processing Record 16 of Set 1, clyde river
# Processing Record 17 of Set 1, vestmanna
# Processing Record 18 of Set 1, taburi
# Processing Record 19 of Set 1, buckeye
# Processing Record 20 of Set 1, albany
# Processing Record 21 of Set 1, north bend
# Processing Record 22 of Set 1, namatanai
# Processing Record 23 of Set 1, aswan
# Processing Record 24 of Set 1, road town
# Processing Record 25 of Set 1, esperance
# Processing Record 26 of Set 1, hilo
# Processing Record 27 of Set 1, savelugu
# Processing Record 28 of Set 1, saint-philippe
# Processing Record 29 of Set 1, rikitea
# Processing Record 30 of Set 1, usak
# Processing Record 31 of Set 1, waiouru
# Processing Record 32 of Set 1, olafsvik
# Processing Record 33 of Set 1, saint joseph
# Processing Record 34 of Set 1, norman wells
# Processing Record 35 of Set 1, filipesti
# Processing Record 36 of Set 1, darhan
# Processing Record 37 of Set 1, mpika
# Processing Record 38 of Set 1, butaritari
# Processing Record 39 of Set 1, bereda
# Processing Record 40 of Set 1, dekoa
# Processing Record 41 of Set 1, chumikan
# Processing Record 42 of Set 1, carnarvon
# Processing Record 43 of Set 1, jamestown
# Processing Record 44 of Set 1, mar del plata
# Processing Record 45 of Set 1, chifeng
# Processing Record 46 of Set 1, chuy
# Processing Record 47 of Set 1, lebu
# Processing Record 48 of Set 1, provideniya
# Processing Record 49 of Set 1, padang
# Processing Record 50 of Set 1, georgetown
# Processing Record 1 of Set 2, longyearbyen
# Processing Record 2 of Set 2, souillac
# Processing Record 3 of Set 2, illoqqortoormiut
# Processing Record 4 of Set 2, port alfred
# Processing Record 5 of Set 2, ribeira grande
# Processing Record 6 of Set 2, dunedin
# Processing Record 7 of Set 2, tuktoyaktuk
# Processing Record 8 of Set 2, ushuaia
# Processing Record 9 of Set 2, banda aceh
# Processing Record 10 of Set 2, kirakira
# Processing Record 11 of Set 2, thompson
# Processing Record 12 of Set 2, shchelyayur
# Processing Record 13 of Set 2, taolanaro
# Processing Record 14 of Set 2, hobart
# Processing Record 15 of Set 2, carutapera
# Processing Record 16 of Set 2, clyde river
# Processing Record 17 of Set 2, vestmanna
# Processing Record 18 of Set 2, taburi
# Processing Record 19 of Set 2, buckeye
# Processing Record 20 of Set 2, albany
# Processing Record 21 of Set 2, north bend
# Processing Record 22 of Set 2, namatanai
# Processing Record 23 of Set 2, aswan
# Processing Record 24 of Set 2, road town
# Processing Record 25 of Set 2, esperance
# Processing Record 26 of Set 2, hilo
# Processing Record 27 of Set 2, savelugu
# Processing Record 28 of Set 2, saint-philippe
# Processing Record 29 of Set 2, rikitea
# Processing Record 30 of Set 2, usak
# Processing Record 31 of Set 2, waiouru
# Processing Record 32 of Set 2, olafsvik
# Processing Record 33 of Set 2, saint joseph
# Processing Record 34 of Set 2, norman wells
# Processing Record 35 of Set 2, filipesti
# Processing Record 36 of Set 2, darhan
# Processing Record 37 of Set 2, mpika
# Processing Record 38 of Set 2, butaritari
# Processing Record 39 of Set 2, bereda
# Processing Record 40 of Set 2, dekoa
# Processing Record 41 of Set 2, chumikan
# Processing Record 42 of Set 2, carnarvon
# Processing Record 43 of Set 2, jamestown
# Processing Record 44 of Set 2, mar del plata
# Processing Record 45 of Set 2, chifeng
# Processing Record 46 of Set 2, chuy
# Processing Record 47 of Set 2, lebu
# Processing Record 48 of Set 2, provideniya
# Processing Record 49 of Set 2, padang
# Processing Record 50 of Set 2, georgetown
# Processing Record 1 of Set 3, longyearbyen
# Processing Record 2 of Set 3, souillac
# Processing Record 3 of Set 3, illoqqortoormiut
# Processing Record 4 of Set 3, port alfred
# Processing Record 5 of Set 3, ribeira grande
# Processing Record 6 of Set 3, dunedin
# Processing Record 7 of Set 3, tuktoyaktuk
# Processing Record 8 of Set 3, ushuaia
# Processing Record 9 of Set 3, banda aceh
# Processing Record 10 of Set 3, kirakira
# Processing Record 11 of Set 3, thompson
# Processing Record 12 of Set 3, shchelyayur
# Processing Record 13 of Set 3, taolanaro
# Processing Record 14 of Set 3, hobart
# Processing Record 15 of Set 3, carutapera
# Processing Record 16 of Set 3, clyde river
# Processing Record 17 of Set 3, vestmanna
# Processing Record 18 of Set 3, taburi
# Processing Record 19 of Set 3, buckeye
# Processing Record 20 of Set 3, albany
# Processing Record 21 of Set 3, north bend
# Processing Record 22 of Set 3, namatanai
# Processing Record 23 of Set 3, aswan
# Processing Record 24 of Set 3, road town
# Processing Record 25 of Set 3, esperance
# Processing Record 26 of Set 3, hilo
# Processing Record 27 of Set 3, savelugu
# Processing Record 28 of Set 3, saint-philippe
# Processing Record 29 of Set 3, rikitea
# Processing Record 30 of Set 3, usak
# Processing Record 31 of Set 3, waiouru
# Processing Record 32 of Set 3, olafsvik
# Processing Record 33 of Set 3, saint joseph
# Processing Record 34 of Set 3, norman wells
# Processing Record 35 of Set 3, filipesti
# Processing Record 36 of Set 3, darhan
# Processing Record 37 of Set 3, mpika
# Processing Record 38 of Set 3, butaritari
# Processing Record 39 of Set 3, bereda
# Processing Record 40 of Set 3, dekoa
# Processing Record 41 of Set 3, chumikan
# Processing Record 42 of Set 3, carnarvon
# Processing Record 43 of Set 3, jamestown
# Processing Record 44 of Set 3, mar del plata
# Processing Record 45 of Set 3, chifeng
# Processing Record 46 of Set 3, chuy
# Processing Record 47 of Set 3, lebu
# Processing Record 48 of Set 3, provideniya
# Processing Record 49 of Set 3, padang
# Processing Record 50 of Set 3, georgetown
# Processing Record 1 of Set 4, longyearbyen
# Processing Record 2 of Set 4, souillac
# Processing Record 3 of Set 4, illoqqortoormiut
# Processing Record 4 of Set 4, port alfred
# Processing Record 5 of Set 4, ribeira grande
# Processing Record 6 of Set 4, dunedin
# Processing Record 7 of Set 4, tuktoyaktuk
# Processing Record 8 of Set 4, ushuaia
# Processing Record 9 of Set 4, banda aceh
# Processing Record 10 of Set 4, kirakira
# Processing Record 11 of Set 4, thompson
# Processing Record 12 of Set 4, shchelyayur
# Processing Record 13 of Set 4, taolanaro
# Processing Record 14 of Set 4, hobart
# Processing Record 15 of Set 4, carutapera
# Processing Record 16 of Set 4, clyde river
# Processing Record 17 of Set 4, vestmanna
# Processing Record 18 of Set 4, taburi
# Processing Record 19 of Set 4, buckeye
# Processing Record 20 of Set 4, albany
# Processing Record 21 of Set 4, north bend
# Processing Record 22 of Set 4, namatanai
# Processing Record 23 of Set 4, aswan
# Processing Record 24 of Set 4, road town
# Processing Record 25 of Set 4, esperance
# Processing Record 26 of Set 4, hilo
# Processing Record 27 of Set 4, savelugu
# Processing Record 28 of Set 4, saint-philippe
# Processing Record 29 of Set 4, rikitea
# Processing Record 30 of Set 4, usak
# Processing Record 31 of Set 4, waiouru
# Processing Record 32 of Set 4, olafsvik
# Processing Record 33 of Set 4, saint joseph
# Processing Record 34 of Set 4, norman wells
# Processing Record 35 of Set 4, filipesti
# Processing Record 36 of Set 4, darhan
# Processing Record 37 of Set 4, mpika
# Processing Record 38 of Set 4, butaritari
# Processing Record 39 of Set 4, bereda
# Processing Record 40 of Set 4, dekoa
# Processing Record 41 of Set 4, chumikan
# Processing Record 42 of Set 4, carnarvon
# Processing Record 43 of Set 4, jamestown
# Processing Record 44 of Set 4, mar del plata
# Processing Record 45 of Set 4, chifeng
# Processing Record 46 of Set 4, chuy
# Processing Record 47 of Set 4, lebu
# Processing Record 48 of Set 4, provideniya
# Processing Record 49 of Set 4, padang
# Processing Record 50 of Set 4, georgetown
# Processing Record 1 of Set 5, longyearbyen
# Processing Record 2 of Set 5, souillac
# Processing Record 3 of Set 5, illoqqortoormiut
# Processing Record 4 of Set 5, port alfred
# Processing Record 5 of Set 5, ribeira grande
# Processing Record 6 of Set 5, dunedin
# Processing Record 7 of Set 5, tuktoyaktuk
# Processing Record 8 of Set 5, ushuaia
# Processing Record 9 of Set 5, banda aceh
# Processing Record 10 of Set 5, kirakira
# Processing Record 11 of Set 5, thompson
# Processing Record 12 of Set 5, shchelyayur
# Processing Record 13 of Set 5, taolanaro
# Processing Record 14 of Set 5, hobart
# Processing Record 15 of Set 5, carutapera
# Processing Record 16 of Set 5, clyde river
# Processing Record 17 of Set 5, vestmanna
# Processing Record 18 of Set 5, taburi
# Processing Record 19 of Set 5, buckeye
# Processing Record 20 of Set 5, albany
# Processing Record 21 of Set 5, north bend
# Processing Record 22 of Set 5, namatanai
# Processing Record 23 of Set 5, aswan
# Processing Record 24 of Set 5, road town
# Processing Record 25 of Set 5, esperance
# Processing Record 26 of Set 5, hilo
# Processing Record 27 of Set 5, savelugu
# Processing Record 28 of Set 5, saint-philippe
# Processing Record 29 of Set 5, rikitea
# Processing Record 30 of Set 5, usak
# Processing Record 31 of Set 5, waiouru
# Processing Record 32 of Set 5, olafsvik
# Processing Record 33 of Set 5, saint joseph
# Processing Record 34 of Set 5, norman wells
# Processing Record 35 of Set 5, filipesti
# Processing Record 36 of Set 5, darhan
# Processing Record 37 of Set 5, mpika
# Processing Record 38 of Set 5, butaritari
# Processing Record 39 of Set 5, bereda
# Processing Record 40 of Set 5, dekoa
# Processing Record 41 of Set 5, chumikan
# Processing Record 42 of Set 5, carnarvon
# Processing Record 43 of Set 5, jamestown
# Processing Record 44 of Set 5, mar del plata
# Processing Record 45 of Set 5, chifeng
# Processing Record 46 of Set 5, chuy
# Processing Record 47 of Set 5, lebu
# Processing Record 48 of Set 5, provideniya
# Processing Record 49 of Set 5, padang
# Processing Record 50 of Set 5, georgetown
# Processing Record 1 of Set 6, longyearbyen
# Processing Record 2 of Set 6, souillac
# Processing Record 3 of Set 6, illoqqortoormiut
# Processing Record 4 of Set 6, port alfred
# Processing Record 5 of Set 6, ribeira grande
# Processing Record 6 of Set 6, dunedin
# Processing Record 7 of Set 6, tuktoyaktuk
# Processing Record 8 of Set 6, ushuaia
# Processing Record 9 of Set 6, banda aceh
# Processing Record 10 of Set 6, kirakira
# Processing Record 11 of Set 6, thompson
# Processing Record 12 of Set 6, shchelyayur
# Processing Record 13 of Set 6, taolanaro
# Processing Record 14 of Set 6, hobart
# Processing Record 15 of Set 6, carutapera
# Processing Record 16 of Set 6, clyde river
# Processing Record 17 of Set 6, vestmanna
# Processing Record 18 of Set 6, taburi
# Processing Record 19 of Set 6, buckeye
# Processing Record 20 of Set 6, albany
# Processing Record 21 of Set 6, north bend
# Processing Record 22 of Set 6, namatanai
# Processing Record 23 of Set 6, aswan
# Processing Record 24 of Set 6, road town
# Processing Record 25 of Set 6, esperance
# Processing Record 26 of Set 6, hilo
# Processing Record 27 of Set 6, savelugu
# Processing Record 28 of Set 6, saint-philippe
# Processing Record 29 of Set 6, rikitea
# Processing Record 30 of Set 6, usak
# Processing Record 31 of Set 6, waiouru
# Processing Record 32 of Set 6, olafsvik
# Processing Record 33 of Set 6, saint joseph
# Processing Record 34 of Set 6, norman wells
# Processing Record 35 of Set 6, filipesti
# Processing Record 36 of Set 6, darhan
# Processing Record 37 of Set 6, mpika
# Processing Record 38 of Set 6, butaritari
# Processing Record 39 of Set 6, bereda
# Processing Record 40 of Set 6, dekoa
# Processing Record 41 of Set 6, chumikan
# Processing Record 42 of Set 6, carnarvon
# Processing Record 43 of Set 6, jamestown
# Processing Record 44 of Set 6, mar del plata
# Processing Record 45 of Set 6, chifeng
# Processing Record 46 of Set 6, chuy
# Processing Record 47 of Set 6, lebu
# Processing Record 48 of Set 6, provideniya
# Processing Record 49 of Set 6, padang
# Processing Record 50 of Set 6, georgetown
# Processing Record 1 of Set 7, longyearbyen
# Processing Record 2 of Set 7, souillac
# Processing Record 3 of Set 7, illoqqortoormiut
# Processing Record 4 of Set 7, port alfred
# Processing Record 5 of Set 7, ribeira grande
# Processing Record 6 of Set 7, dunedin
# Processing Record 7 of Set 7, tuktoyaktuk
# Processing Record 8 of Set 7, ushuaia
# Processing Record 9 of Set 7, banda aceh
# Processing Record 10 of Set 7, kirakira
# Processing Record 11 of Set 7, thompson
# Processing Record 12 of Set 7, shchelyayur
# Processing Record 13 of Set 7, taolanaro
# Processing Record 14 of Set 7, hobart
# Processing Record 15 of Set 7, carutapera
# Processing Record 16 of Set 7, clyde river
# Processing Record 17 of Set 7, vestmanna
# Processing Record 18 of Set 7, taburi
# Processing Record 19 of Set 7, buckeye
# Processing Record 20 of Set 7, albany
# Processing Record 21 of Set 7, north bend
# Processing Record 22 of Set 7, namatanai
# Processing Record 23 of Set 7, aswan
# Processing Record 24 of Set 7, road town
# Processing Record 25 of Set 7, esperance
# Processing Record 26 of Set 7, hilo
# Processing Record 27 of Set 7, savelugu
# Processing Record 28 of Set 7, saint-philippe
# Processing Record 29 of Set 7, rikitea
# Processing Record 30 of Set 7, usak
# Processing Record 31 of Set 7, waiouru
# Processing Record 32 of Set 7, olafsvik
# Processing Record 33 of Set 7, saint joseph
# Processing Record 34 of Set 7, norman wells
# Processing Record 35 of Set 7, filipesti
# Processing Record 36 of Set 7, darhan
# Processing Record 37 of Set 7, mpika
# Processing Record 38 of Set 7, butaritari
# Processing Record 39 of Set 7, bereda
# Processing Record 40 of Set 7, dekoa
# Processing Record 41 of Set 7, chumikan
# Processing Record 42 of Set 7, carnarvon
# Processing Record 43 of Set 7, jamestown
# Processing Record 44 of Set 7, mar del plata
# Processing Record 45 of Set 7, chifeng
# Processing Record 46 of Set 7, chuy
# Processing Record 47 of Set 7, lebu
# Processing Record 48 of Set 7, provideniya
# Processing Record 49 of Set 7, padang
# Processing Record 50 of Set 7, georgetown
# Processing Record 1 of Set 8, longyearbyen
# Processing Record 2 of Set 8, souillac
# Processing Record 3 of Set 8, illoqqortoormiut
# Processing Record 4 of Set 8, port alfred
# Processing Record 5 of Set 8, ribeira grande
# Processing Record 6 of Set 8, dunedin
# Processing Record 7 of Set 8, tuktoyaktuk
# Processing Record 8 of Set 8, ushuaia
# Processing Record 9 of Set 8, banda aceh
# Processing Record 10 of Set 8, kirakira
# Processing Record 11 of Set 8, thompson
# Processing Record 12 of Set 8, shchelyayur
# Processing Record 13 of Set 8, taolanaro
# Processing Record 14 of Set 8, hobart
# Processing Record 15 of Set 8, carutapera
# Processing Record 16 of Set 8, clyde river
# Processing Record 17 of Set 8, vestmanna
# Processing Record 18 of Set 8, taburi
# Processing Record 19 of Set 8, buckeye
# Processing Record 20 of Set 8, albany
# Processing Record 21 of Set 8, north bend
# Processing Record 22 of Set 8, namatanai
# Processing Record 23 of Set 8, aswan
# Processing Record 24 of Set 8, road town
# Processing Record 25 of Set 8, esperance
# Processing Record 26 of Set 8, hilo
# Processing Record 27 of Set 8, savelugu
# Processing Record 28 of Set 8, saint-philippe
# Processing Record 29 of Set 8, rikitea
# Processing Record 30 of Set 8, usak
# Processing Record 31 of Set 8, waiouru
# Processing Record 32 of Set 8, olafsvik
# Processing Record 33 of Set 8, saint joseph
# Processing Record 34 of Set 8, norman wells
# Processing Record 35 of Set 8, filipesti
# Processing Record 36 of Set 8, darhan
# Processing Record 37 of Set 8, mpika
# Processing Record 38 of Set 8, butaritari
# Processing Record 39 of Set 8, bereda
# Processing Record 40 of Set 8, dekoa
# Processing Record 41 of Set 8, chumikan
# Processing Record 42 of Set 8, carnarvon
# Processing Record 43 of Set 8, jamestown
# Processing Record 44 of Set 8, mar del plata
# Processing Record 45 of Set 8, chifeng
# Processing Record 46 of Set 8, chuy
# Processing Record 47 of Set 8, lebu
# Processing Record 48 of Set 8, provideniya
# Processing Record 49 of Set 8, padang
# Processing Record 50 of Set 8, georgetown
# Processing Record 1 of Set 9, longyearbyen
# Processing Record 2 of Set 9, souillac
# Processing Record 3 of Set 9, illoqqortoormiut
# Processing Record 4 of Set 9, port alfred
# Processing Record 5 of Set 9, ribeira grande
# Processing Record 6 of Set 9, dunedin
# Processing Record 7 of Set 9, tuktoyaktuk
# Processing Record 8 of Set 9, ushuaia
# Processing Record 9 of Set 9, banda aceh
# Processing Record 10 of Set 9, kirakira
# Processing Record 11 of Set 9, thompson
# Processing Record 12 of Set 9, shchelyayur
# Processing Record 13 of Set 9, taolanaro
# Processing Record 14 of Set 9, hobart
# Processing Record 15 of Set 9, carutapera
# Processing Record 16 of Set 9, clyde river
# Processing Record 17 of Set 9, vestmanna
# Processing Record 18 of Set 9, taburi
# Processing Record 19 of Set 9, buckeye
# Processing Record 20 of Set 9, albany
# Processing Record 21 of Set 9, north bend
# Processing Record 22 of Set 9, namatanai
# Processing Record 23 of Set 9, aswan
# Processing Record 24 of Set 9, road town
# Processing Record 25 of Set 9, esperance
# Processing Record 26 of Set 9, hilo
# Processing Record 27 of Set 9, savelugu
# Processing Record 28 of Set 9, saint-philippe
# Processing Record 29 of Set 9, rikitea
# Processing Record 30 of Set 9, usak
# Processing Record 31 of Set 9, waiouru
# Processing Record 32 of Set 9, olafsvik
# Processing Record 33 of Set 9, saint joseph
# Processing Record 34 of Set 9, norman wells
# Processing Record 35 of Set 9, filipesti
# Processing Record 36 of Set 9, darhan
# Processing Record 37 of Set 9, mpika
# Processing Record 38 of Set 9, butaritari
# Processing Record 39 of Set 9, bereda
# Processing Record 40 of Set 9, dekoa
# Processing Record 41 of Set 9, chumikan
# Processing Record 42 of Set 9, carnarvon
# Processing Record 43 of Set 9, jamestown
# Processing Record 44 of Set 9, mar del plata
# Processing Record 45 of Set 9, chifeng
# Processing Record 46 of Set 9, chuy
# Processing Record 47 of Set 9, lebu
# Processing Record 48 of Set 9, provideniya
# Processing Record 49 of Set 9, padang
# Processing Record 50 of Set 9, georgetown
# Processing Record 1 of Set 10, longyearbyen
# Processing Record 2 of Set 10, souillac
# Processing Record 3 of Set 10, illoqqortoormiut
# Processing Record 4 of Set 10, port alfred
# Processing Record 5 of Set 10, ribeira grande
# Processing Record 6 of Set 10, dunedin
# Processing Record 7 of Set 10, tuktoyaktuk
# Processing Record 8 of Set 10, ushuaia
# Processing Record 9 of Set 10, banda aceh
# Processing Record 10 of Set 10, kirakira
# Processing Record 11 of Set 10, thompson
# Processing Record 12 of Set 10, shchelyayur
# Processing Record 13 of Set 10, taolanaro
# Processing Record 14 of Set 10, hobart
# Processing Record 15 of Set 10, carutapera
# Processing Record 16 of Set 10, clyde river
# Processing Record 17 of Set 10, vestmanna
# Processing Record 18 of Set 10, taburi
# Processing Record 19 of Set 10, buckeye
# Processing Record 20 of Set 10, albany
# Processing Record 21 of Set 10, north bend
# Processing Record 22 of Set 10, namatanai
# Processing Record 23 of Set 10, aswan
# Processing Record 24 of Set 10, road town
# Processing Record 25 of Set 10, esperance
# Processing Record 26 of Set 10, hilo
# Processing Record 27 of Set 10, savelugu
# Processing Record 28 of Set 10, saint-philippe
# Processing Record 29 of Set 10, rikitea
# Processing Record 30 of Set 10, usak
# Processing Record 31 of Set 10, waiouru
# Processing Record 32 of Set 10, olafsvik
# Processing Record 33 of Set 10, saint joseph
# Processing Record 34 of Set 10, norman wells
# Processing Record 35 of Set 10, filipesti
# Processing Record 36 of Set 10, darhan
# Processing Record 37 of Set 10, mpika
# Processing Record 38 of Set 10, butaritari
# Processing Record 39 of Set 10, bereda
# Processing Record 40 of Set 10, dekoa
# Processing Record 41 of Set 10, chumikan
# Processing Record 42 of Set 10, carnarvon
# Processing Record 43 of Set 10, jamestown
# Processing Record 44 of Set 10, mar del plata
# Processing Record 45 of Set 10, chifeng
# Processing Record 46 of Set 10, chuy
# Processing Record 47 of Set 10, lebu
# Processing Record 48 of Set 10, provideniya
# Processing Record 49 of Set 10, padang
# Processing Record 50 of Set 10, georgetown
# Processing Record 1 of Set 11, longyearbyen
# Processing Record 2 of Set 11, souillac
# Processing Record 3 of Set 11, illoqqortoormiut
# Processing Record 4 of Set 11, port alfred
# Processing Record 5 of Set 11, ribeira grande
# Processing Record 6 of Set 11, dunedin
# Processing Record 7 of Set 11, tuktoyaktuk
# Processing Record 8 of Set 11, ushuaia
# Processing Record 9 of Set 11, banda aceh
# Processing Record 10 of Set 11, kirakira
# Processing Record 11 of Set 11, thompson
# Processing Record 12 of Set 11, shchelyayur
# Processing Record 13 of Set 11, taolanaro
# Processing Record 14 of Set 11, hobart
# Processing Record 15 of Set 11, carutapera
# Processing Record 16 of Set 11, clyde river
# Processing Record 17 of Set 11, vestmanna
# Processing Record 18 of Set 11, taburi
# Processing Record 19 of Set 11, buckeye
# Processing Record 20 of Set 11, albany
# Processing Record 21 of Set 11, north bend
# Processing Record 22 of Set 11, namatanai
# Processing Record 23 of Set 11, aswan
# Processing Record 24 of Set 11, road town
# Processing Record 25 of Set 11, esperance
# Processing Record 26 of Set 11, hilo
# Processing Record 27 of Set 11, savelugu
# Processing Record 28 of Set 11, saint-philippe
# Processing Record 29 of Set 11, rikitea
# Processing Record 30 of Set 11, usak
# Processing Record 31 of Set 11, waiouru
# Processing Record 32 of Set 11, olafsvik
# Processing Record 33 of Set 11, saint joseph
# Processing Record 34 of Set 11, norman wells
# Processing Record 35 of Set 11, filipesti
# Processing Record 36 of Set 11, darhan
# Processing Record 37 of Set 11, mpika
# Processing Record 38 of Set 11, butaritari
# Processing Record 39 of Set 11, bereda
# Processing Record 40 of Set 11, dekoa
# Processing Record 41 of Set 11, chumikan
# Processing Record 42 of Set 11, carnarvon
# Processing Record 43 of Set 11, jamestown
# Processing Record 44 of Set 11, mar del plata
# Processing Record 45 of Set 11, chifeng
# Processing Record 46 of Set 11, chuy
# Processing Record 47 of Set 11, lebu
# Processing Record 48 of Set 11, provideniya
# Processing Record 49 of Set 11, padang
# Processing Record 50 of Set 11, georgetown
# Processing Record 1 of Set 12, longyearbyen
# Processing Record 2 of Set 12, souillac
# Processing Record 3 of Set 12, illoqqortoormiut
# Processing Record 4 of Set 12, port alfred
# Processing Record 5 of Set 12, ribeira grande
# Processing Record 6 of Set 12, dunedin
# Processing Record 7 of Set 12, tuktoyaktuk
# Processing Record 8 of Set 12, ushuaia
# Processing Record 9 of Set 12, banda aceh
# Processing Record 10 of Set 12, kirakira
# Processing Record 11 of Set 12, thompson
# Processing Record 12 of Set 12, shchelyayur
# Processing Record 13 of Set 12, taolanaro
# Processing Record 14 of Set 12, hobart
# Processing Record 15 of Set 12, carutapera
# Processing Record 16 of Set 12, clyde river
# Processing Record 17 of Set 12, vestmanna
# Processing Record 18 of Set 12, taburi
# Processing Record 19 of Set 12, buckeye
# Processing Record 20 of Set 12, albany
# Processing Record 21 of Set 12, north bend
# Processing Record 22 of Set 12, namatanai
# Processing Record 23 of Set 12, aswan
# Processing Record 24 of Set 12, road town
# Processing Record 25 of Set 12, esperance
# Processing Record 26 of Set 12, hilo
# Processing Record 27 of Set 12, savelugu
# Processing Record 28 of Set 12, saint-philippe
# Processing Record 29 of Set 12, rikitea
# Processing Record 30 of Set 12, usak
# Processing Record 31 of Set 12, waiouru
# Processing Record 32 of Set 12, olafsvik
# Processing Record 33 of Set 12, saint joseph
# Processing Record 34 of Set 12, norman wells
# Processing Record 35 of Set 12, filipesti
# Processing Record 36 of Set 12, darhan
# Processing Record 37 of Set 12, mpika
# Processing Record 38 of Set 12, butaritari
# Processing Record 39 of Set 12, bereda
# Processing Record 40 of Set 12, dekoa
# Processing Record 41 of Set 12, chumikan
# Processing Record 42 of Set 12, carnarvon
# Processing Record 43 of Set 12, jamestown
# Processing Record 44 of Set 12, mar del plata
# Processing Record 45 of Set 12, chifeng
# Processing Record 46 of Set 12, chuy
# Processing Record 47 of Set 12, lebu
# Processing Record 48 of Set 12, provideniya
# Processing Record 49 of Set 12, padang
# Processing Record 50 of Set 12, georgetown
# Processing Record 1 of Set 13, longyearbyen
# Processing Record 2 of Set 13, souillac
# Processing Record 3 of Set 13, illoqqortoormiut
# Processing Record 4 of Set 13, port alfred
# Processing Record 5 of Set 13, ribeira grande
# Processing Record 6 of Set 13, dunedin
# Processing Record 7 of Set 13, tuktoyaktuk
# Processing Record 8 of Set 13, ushuaia
# Processing Record 9 of Set 13, banda aceh

# %%
df=pd.DataFrame({"city": cities})
#df.head()

# %%
df.to_csv(output_data_file)

# %%
csv_path = "output/cities.csv"
cities_df = pd.read_csv(csv_path)
cities_df.head()
# Out:
#    Unnamed: 0              city
# 0           0      port lincoln
# 1           1          souillac
# 2           2  illoqqortoormiut
# 3           3       port alfred
# 4           4    ribeira grande

# %%
#find Cloudiness, country, date, humidity, lat, lng, max temp, wind speed 
test_city = "lompoc"
base_url = "http://api.openweathermap.org/data/2.5/weather?"
test_url = f"{base_url}appid={api_key}&q={test_city}"
response=requests.get(test_url).json()

# %%
#pprint(response)
clouds = response["clouds"]["all"]
country=response["sys"]["country"]
date= response["dt"]
humidity=response["main"]["humidity"]
lat=response["coord"]["lat"]
lng=response["coord"]["lon"]
max_temp=response["main"]["temp_max"]
wind=response["wind"]["speed"]
clouds
# Out:
# 1

# %%
cities_df["Cloudiness"]=""
cities_df["Country"]=""
cities_df["Date"]=""
cities_df["Humidity"]=""
cities_df["Lat"]=""
cities_df["Lng"]=""
cities_df["Max Temp"]=""
cities_df["Wind Speed"]=""

# %%
x=0
for index, row in cities_df.iterrows(): 
    target_city=row["city"]
    query_url= f"{base_url}appid={api_key}&q={target_city}"
    response=requests.get(query_url).json()
    try:
        clouds=response["clouds"]["all"]
        cities_df.set_value(x, "Cloudiness", clouds)
    except KeyError:
        cities_df.set_value(x, "Cloudiness", np.NAN)
    try:
        country=response["sys"]["country"]
        cities_df.set_value(x, "Country", country)
    except KeyError:
         cities_df.set_value(x, "Country", np.NAN)
    try:
        date=response["dt"]
        cities_df.set_value(x, "Date", date)
    except KeyError:
         cities_df.set_value(x, "Date", np.NAN)
    try:
        humidity=response["main"]["humidity"]
        cities_df.set_value(x, "Humidity", humidity)
    except KeyError:
         cities_df.set_value(x, "Humidity", np.NAN)
    try:    
        lat=response["coord"]["lat"]
        cities_df.set_value(x, "Lat", lat)
    except KeyError:
         cities_df.set_value(x, "Lat", np.NAN)
    try:
        lng=response["coord"]["lon"]
        cities_df.set_value(x, "Lng", lng)
    except KeyError:
         cities_df.set_value(x, "Lng", np.NAN)
    try:
        max_temp=response["main"]["temp_max"]
        cities_df.set_value(x, "Max Temp", max_temp)
    except KeyError:
         cities_df.set_value(x, "Max Temp", np.NAN)
    try:
        wind=response["wind"]["speed"]
        cities_df.set_value(x, "Wind Speed", wind)
    except KeyError: 
         cities_df.set_value(x, "Wind Speed", np.NAN)
            
    x+=1
# Out:
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Elsa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
drop_cities = cities_df
drop_cities = non.dropna()

# %%
drop_cities.head()
# Out:
#                       city Cloudiness Country        Date Humidity    Lat  \
# Unnamed: 0
# 0             port lincoln          0      AU  1553051056       86 -34.72
# 1                 souillac          0      FR  1553050988       93   45.6
# 3              port alfred         76      ZA  1553051075       91 -33.59
# 4           ribeira grande         64      PT  1553051090       98  38.52
# 5                  dunedin          0      NZ  1553050413       78 -45.87
#
#                Lng Max Temp Wind Speed
# Unnamed: 0
# 0           135.86  293.855       3.37
# 1             -0.6   278.15        0.5
# 3            26.89   293.71       3.13
# 4            -28.7  288.555       5.92
# 5            170.5   290.37       1.34

# %%
drop_cities.count()
# Out:
# city          534
# Cloudiness    534
# Country       534
# Date          534
# Humidity      534
# Lat           534
# Lng           534
# Max Temp      534
# Wind Speed    534
# dtype: int64

# %%
lat_axis = drop_cities["Lat"]
temp_axis = drop_cities["Max Temp"]
humidity_axis = drop_cities["Humidity"]
cloud_axis = drop_cities["Cloudiness"]
wind_axis = drop_cities["Wind Speed"]

# %%
plt.scatter(lat_axis,temp_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(lat_axis,humidity_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(lat_axis,cloud_axis)
plt.show()

# %%
plt.scatter(lat_axis,wind_axis)
plt.show()
