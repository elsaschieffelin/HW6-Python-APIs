# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import json
from pprint import pprint
from api_key import api_key
from citipy import citipy

# %% [markdown]
# # Generate Random City Data

# %%
output_data_file = "output/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 620

# %% [markdown]
# # API Calls

# %%
base_url = "api.openweathermap.org/data/2.5/weather?"
x=0
for city in cities:  
    city = cities[x]
    try:
        target_url = f"{base_url}appid={api_key}&q={city}"
        print(f"Processing {x} of set, {city}")
    except NameError: 
        print("city not found. Skipping...")
    x=x+1
# Out:
# Processing 0 of set, pemangkat
# Processing 1 of set, tiznit
# Processing 2 of set, vila franca do campo
# Processing 3 of set, iqaluit
# Processing 4 of set, qaanaaq
# Processing 5 of set, cockburn town
# Processing 6 of set, talnakh
# Processing 7 of set, hermanus
# Processing 8 of set, cherskiy
# Processing 9 of set, jamestown
# Processing 10 of set, atuona
# Processing 11 of set, luocheng
# Processing 12 of set, los llanos de aridane
# Processing 13 of set, new norfolk
# Processing 14 of set, bambanglipuro
# Processing 15 of set, rikitea
# Processing 16 of set, hilo
# Processing 17 of set, illoqqortoormiut
# Processing 18 of set, east london
# Processing 19 of set, hobart
# Processing 20 of set, vaini
# Processing 21 of set, baykit
# Processing 22 of set, somerset east
# Processing 23 of set, guayaramerin
# Processing 24 of set, beloha
# Processing 25 of set, calafell
# Processing 26 of set, paamiut
# Processing 27 of set, kaohsiung
# Processing 28 of set, sao filipe
# Processing 29 of set, port alfred
# Processing 30 of set, matamoros
# Processing 31 of set, tabou
# Processing 32 of set, ondjiva
# Processing 33 of set, ushuaia
# Processing 34 of set, thompson
# Processing 35 of set, tommot
# Processing 36 of set, punta alta
# Processing 37 of set, saint-philippe
# Processing 38 of set, bluff
# Processing 39 of set, lavrentiya
# Processing 40 of set, aklavik
# Processing 41 of set, ponta do sol
# Processing 42 of set, kapaa
# Processing 43 of set, vila velha
# Processing 44 of set, busselton
# Processing 45 of set, mataura
# Processing 46 of set, portland
# Processing 47 of set, grand gaube
# Processing 48 of set, albany
# Processing 49 of set, georgetown
# Processing 50 of set, mehamn
# Processing 51 of set, avarua
# Processing 52 of set, mys shmidta
# Processing 53 of set, iisalmi
# Processing 54 of set, belushya guba
# Processing 55 of set, cabo san lucas
# Processing 56 of set, victoria
# Processing 57 of set, oktyabrskoye
# Processing 58 of set, ibotirama
# Processing 59 of set, sorland
# Processing 60 of set, husavik
# Processing 61 of set, sur
# Processing 62 of set, livingston
# Processing 63 of set, hopfgarten
# Processing 64 of set, aksha
# Processing 65 of set, mansa
# Processing 66 of set, tabory
# Processing 67 of set, airai
# Processing 68 of set, yellowknife
# Processing 69 of set, punta arenas
# Processing 70 of set, carnarvon
# Processing 71 of set, tual
# Processing 72 of set, mar del plata
# Processing 73 of set, pangnirtung
# Processing 74 of set, leningradskiy
# Processing 75 of set, luxor
# Processing 76 of set, saskylakh
# Processing 77 of set, concordia
# Processing 78 of set, inirida
# Processing 79 of set, kochubey
# Processing 80 of set, richards bay
# Processing 81 of set, mandleshwar
# Processing 82 of set, tir pol
# Processing 83 of set, bay roberts
# Processing 84 of set, goba
# Processing 85 of set, asau
# Processing 86 of set, chuy
# Processing 87 of set, waipawa
# Processing 88 of set, gombong
# Processing 89 of set, ust-ishim
# Processing 90 of set, kahului
# Processing 91 of set, souillac
# Processing 92 of set, port elizabeth
# Processing 93 of set, pevek
# Processing 94 of set, palabuhanratu
# Processing 95 of set, port lincoln
# Processing 96 of set, dicabisagan
# Processing 97 of set, aykhal
# Processing 98 of set, khatanga
# Processing 99 of set, barentsburg
# Processing 100 of set, wuda
# Processing 101 of set, baoying
# Processing 102 of set, lagoa
# Processing 103 of set, papetoai
# Processing 104 of set, freeport
# Processing 105 of set, pietarsaari
# Processing 106 of set, pisco
# Processing 107 of set, shenjiamen
# Processing 108 of set, ribeira grande
# Processing 109 of set, shache
# Processing 110 of set, huntington
# Processing 111 of set, tasiilaq
# Processing 112 of set, pitimbu
# Processing 113 of set, aksu
# Processing 114 of set, hithadhoo
# Processing 115 of set, marcona
# Processing 116 of set, klaksvik
# Processing 117 of set, santa comba
# Processing 118 of set, half moon bay
# Processing 119 of set, leh
# Processing 120 of set, srednekolymsk
# Processing 121 of set, progreso
# Processing 122 of set, sisimiut
# Processing 123 of set, lorengau
# Processing 124 of set, havoysund
# Processing 125 of set, amderma
# Processing 126 of set, mecca
# Processing 127 of set, netishyn
# Processing 128 of set, taolanaro
# Processing 129 of set, luderitz
# Processing 130 of set, college
# Processing 131 of set, kangaatsiaq
# Processing 132 of set, arraial do cabo
# Processing 133 of set, primorsk
# Processing 134 of set, mayumba
# Processing 135 of set, carmiano
# Processing 136 of set, laguna
# Processing 137 of set, bejar
# Processing 138 of set, vrangel
# Processing 139 of set, cape town
# Processing 140 of set, kuito
# Processing 141 of set, vidim
# Processing 142 of set, luena
# Processing 143 of set, nikolskoye
# Processing 144 of set, benguela
# Processing 145 of set, cidreira
# Processing 146 of set, velingara
# Processing 147 of set, nenjiang
# Processing 148 of set, bouza
# Processing 149 of set, preston
# Processing 150 of set, bayir
# Processing 151 of set, grand river south east
# Processing 152 of set, severo-kurilsk
# Processing 153 of set, zhoucheng
# Processing 154 of set, salalah
# Processing 155 of set, iquique
# Processing 156 of set, hachinohe
# Processing 157 of set, namatanai
# Processing 158 of set, adrar
# Processing 159 of set, norman wells
# Processing 160 of set, ariquemes
# Processing 161 of set, gujan-mestras
# Processing 162 of set, bathsheba
# Processing 163 of set, mahebourg
# Processing 164 of set, kodiak
# Processing 165 of set, saint-hyacinthe
# Processing 166 of set, fortuna
# Processing 167 of set, san cristobal
# Processing 168 of set, longyearbyen
# Processing 169 of set, spearfish
# Processing 170 of set, torbay
# Processing 171 of set, lompoc
# Processing 172 of set, pontes e lacerda
# Processing 173 of set, makokou
# Processing 174 of set, zhitikara
# Processing 175 of set, dikson
# Processing 176 of set, bilibino
# Processing 177 of set, schwarzenberg
# Processing 178 of set, ambilobe
# Processing 179 of set, tazovskiy
# Processing 180 of set, tsaratanana
# Processing 181 of set, gazli
# Processing 182 of set, puerto ayora
# Processing 183 of set, laki
# Processing 184 of set, yar-sale
# Processing 185 of set, amapa
# Processing 186 of set, samusu
# Processing 187 of set, upernavik
# Processing 188 of set, praia da vitoria
# Processing 189 of set, tuatapere
# Processing 190 of set, nizhneyansk
# Processing 191 of set, kholodnyy
# Processing 192 of set, gudur
# Processing 193 of set, port macquarie
# Processing 194 of set, tapikan
# Processing 195 of set, abdulino
# Processing 196 of set, vaitupu
# Processing 197 of set, castro
# Processing 198 of set, mount isa
# Processing 199 of set, tura
# Processing 200 of set, zhigansk
# Processing 201 of set, narsaq
# Processing 202 of set, saint george
# Processing 203 of set, mouzakion
# Processing 204 of set, baker city
# Processing 205 of set, marolambo
# Processing 206 of set, esperance
# Processing 207 of set, mahon
# Processing 208 of set, broken hill
# Processing 209 of set, tidore
# Processing 210 of set, butaritari
# Processing 211 of set, tuktoyaktuk
# Processing 212 of set, martapura
# Processing 213 of set, waingapu
# Processing 214 of set, tiksi
# Processing 215 of set, nishihara
# Processing 216 of set, puerto escondido
# Processing 217 of set, methoni
# Processing 218 of set, hamilton
# Processing 219 of set, nelson bay
# Processing 220 of set, outjo
# Processing 221 of set, abu samrah
# Processing 222 of set, suez
# Processing 223 of set, port hardy
# Processing 224 of set, kampong chhnang
# Processing 225 of set, excelsior springs
# Processing 226 of set, coihaique
# Processing 227 of set, edgewater
# Processing 228 of set, provideniya
# Processing 229 of set, bokoro
# Processing 230 of set, ilulissat
# Processing 231 of set, brae
# Processing 232 of set, ostrovnoy
# Processing 233 of set, bambous virieux
# Processing 234 of set, barrow
# Processing 235 of set, matay
# Processing 236 of set, harper
# Processing 237 of set, port keats
# Processing 238 of set, meulaboh
# Processing 239 of set, fort nelson
# Processing 240 of set, siemiatycze
# Processing 241 of set, saint-pierre
# Processing 242 of set, sao joao da barra
# Processing 243 of set, yangambi
# Processing 244 of set, touros
# Processing 245 of set, chokwe
# Processing 246 of set, mancio lima
# Processing 247 of set, corn island
# Processing 248 of set, pacific grove
# Processing 249 of set, margate
# Processing 250 of set, bolshoye soldatskoye
# Processing 251 of set, berlevag
# Processing 252 of set, sentyabrskiy
# Processing 253 of set, lydenburg
# Processing 254 of set, kawalu
# Processing 255 of set, haines junction
# Processing 256 of set, isiro
# Processing 257 of set, camana
# Processing 258 of set, chumikan
# Processing 259 of set, man
# Processing 260 of set, kokopo
# Processing 261 of set, san patricio
# Processing 262 of set, marzuq
# Processing 263 of set, karpogory
# Processing 264 of set, sorvag
# Processing 265 of set, quatre cocos
# Processing 266 of set, hasaki
# Processing 267 of set, honningsvag
# Processing 268 of set, belyy yar
# Processing 269 of set, yanan
# Processing 270 of set, cap malheureux
# Processing 271 of set, sofiysk
# Processing 272 of set, ust-ilimsk
# Processing 273 of set, yaqui
# Processing 274 of set, la ronge
# Processing 275 of set, naze
# Processing 276 of set, viligili
# Processing 277 of set, denpasar
# Processing 278 of set, nador
# Processing 279 of set, cassilandia
# Processing 280 of set, elko
# Processing 281 of set, vostok
# Processing 282 of set, gandajika
# Processing 283 of set, klyuchi
# Processing 284 of set, bengkulu
# Processing 285 of set, pandan
# Processing 286 of set, lebu
# Processing 287 of set, santa marta
# Processing 288 of set, ossora
# Processing 289 of set, taybad
# Processing 290 of set, kaitangata
# Processing 291 of set, luanda
# Processing 292 of set, qui nhon
# Processing 293 of set, alotau
# Processing 294 of set, tabuk
# Processing 295 of set, mundra
# Processing 296 of set, waspan
# Processing 297 of set, karkaralinsk
# Processing 298 of set, morti
# Processing 299 of set, shakawe
# Processing 300 of set, makasar
# Processing 301 of set, bam
# Processing 302 of set, beringovskiy
# Processing 303 of set, hofn
# Processing 304 of set, requena
# Processing 305 of set, hobyo
# Processing 306 of set, natal
# Processing 307 of set, seoul
# Processing 308 of set, sioux lookout
# Processing 309 of set, riyadh
# Processing 310 of set, nabire
# Processing 311 of set, vestmannaeyjar
# Processing 312 of set, filadelfia
# Processing 313 of set, cheltenham
# Processing 314 of set, zambezi
# Processing 315 of set, dunning
# Processing 316 of set, chapais
# Processing 317 of set, ust-tarka
# Processing 318 of set, saleaula
# Processing 319 of set, quelimane
# Processing 320 of set, zanjan
# Processing 321 of set, pudozh
# Processing 322 of set, sangar
# Processing 323 of set, karratha
# Processing 324 of set, rio cuarto
# Processing 325 of set, ubeda
# Processing 326 of set, bubaque
# Processing 327 of set, innisfail
# Processing 328 of set, port blair
# Processing 329 of set, ngukurr
# Processing 330 of set, tsihombe
# Processing 331 of set, dingle
# Processing 332 of set, teya
# Processing 333 of set, dunedin
# Processing 334 of set, benghazi
# Processing 335 of set, port-gentil
# Processing 336 of set, povenets
# Processing 337 of set, saint anthony
# Processing 338 of set, rancho cordova
# Processing 339 of set, manaus
# Processing 340 of set, kieta
# Processing 341 of set, krasnoselkup
# Processing 342 of set, phalaborwa
# Processing 343 of set, iringa
# Processing 344 of set, sitka
# Processing 345 of set, broome
# Processing 346 of set, olafsvik
# Processing 347 of set, ananas
# Processing 348 of set, ozinki
# Processing 349 of set, bend
# Processing 350 of set, jati
# Processing 351 of set, kununurra
# Processing 352 of set, iracoubo
# Processing 353 of set, bredasdorp
# Processing 354 of set, bethel
# Processing 355 of set, chernelytsya
# Processing 356 of set, gamba
# Processing 357 of set, coquimbo
# Processing 358 of set, itarema
# Processing 359 of set, fereydun kenar
# Processing 360 of set, itoman
# Processing 361 of set, manacapuru
# Processing 362 of set, dulce nombre de culmi
# Processing 363 of set, turtas
# Processing 364 of set, birao
# Processing 365 of set, genhe
# Processing 366 of set, vallenar
# Processing 367 of set, sohag
# Processing 368 of set, bacuit
# Processing 369 of set, moranbah
# Processing 370 of set, arica
# Processing 371 of set, kula
# Processing 372 of set, lasa
# Processing 373 of set, tumannyy
# Processing 374 of set, lins
# Processing 375 of set, barcelona
# Processing 376 of set, phek
# Processing 377 of set, kloulklubed
# Processing 378 of set, ahumada
# Processing 379 of set, nueve de julio
# Processing 380 of set, wattegama
# Processing 381 of set, palora
# Processing 382 of set, litovko
# Processing 383 of set, mingyue
# Processing 384 of set, grindavik
# Processing 385 of set, qujing
# Processing 386 of set, halalo
# Processing 387 of set, khudumelapye
# Processing 388 of set, plettenberg bay
# Processing 389 of set, karaul
# Processing 390 of set, ukiah
# Processing 391 of set, kavieng
# Processing 392 of set, severobaykalsk
# Processing 393 of set, shingu
# Processing 394 of set, tadine
# Processing 395 of set, pochutla
# Processing 396 of set, kruisfontein
# Processing 397 of set, codrington
# Processing 398 of set, forestville
# Processing 399 of set, aguilas
# Processing 400 of set, cordeiropolis
# Processing 401 of set, constitucion
# Processing 402 of set, labuhan
# Processing 403 of set, goure
# Processing 404 of set, artyk
# Processing 405 of set, saint-louis
# Processing 406 of set, tahlequah
# Processing 407 of set, lamu
# Processing 408 of set, koeru
# Processing 409 of set, leiyang
# Processing 410 of set, bilma
# Processing 411 of set, kimbe
# Processing 412 of set, vitim
# Processing 413 of set, abu dhabi
# Processing 414 of set, igarka
# Processing 415 of set, hassleholm
# Processing 416 of set, boende
# Processing 417 of set, tezu
# Processing 418 of set, hovd
# Processing 419 of set, villa rica
# Processing 420 of set, manokwari
# Processing 421 of set, manali
# Processing 422 of set, si sa ket
# Processing 423 of set, omsukchan
# Processing 424 of set, sandpoint
# Processing 425 of set, abha
# Processing 426 of set, torrox
# Processing 427 of set, evensk
# Processing 428 of set, nagua
# Processing 429 of set, yerbogachen
# Processing 430 of set, hondo
# Processing 431 of set, taoudenni
# Processing 432 of set, mpraeso
# Processing 433 of set, khani
# Processing 434 of set, nantucket
# Processing 435 of set, grand-santi
# Processing 436 of set, catemaco
# Processing 437 of set, mrirt
# Processing 438 of set, monte alegre
# Processing 439 of set, tuy hoa
# Processing 440 of set, yantal
# Processing 441 of set, osa
# Processing 442 of set, matagami
# Processing 443 of set, faanui
# Processing 444 of set, kalabo
# Processing 445 of set, kiri buru
# Processing 446 of set, muros
# Processing 447 of set, atar
# Processing 448 of set, matozinhos
# Processing 449 of set, lagos
# Processing 450 of set, stolin
# Processing 451 of set, roseburg
# Processing 452 of set, nanortalik
# Processing 453 of set, pinega
# Processing 454 of set, dobre miasto
# Processing 455 of set, te anau
# Processing 456 of set, minyar
# Processing 457 of set, mareeba
# Processing 458 of set, nhulunbuy
# Processing 459 of set, zenzeli
# Processing 460 of set, qaqortoq
# Processing 461 of set, ipora
# Processing 462 of set, kazalinsk
# Processing 463 of set, sobolevo
# Processing 464 of set, naruja
# Processing 465 of set, bonanza
# Processing 466 of set, tawkar
# Processing 467 of set, yenagoa
# Processing 468 of set, awjilah
# Processing 469 of set, kashi
# Processing 470 of set, ponta delgada
# Processing 471 of set, tautira
# Processing 472 of set, taltal
# Processing 473 of set, geraldton
# Processing 474 of set, keetmanshoop
# Processing 475 of set, clyde river
# Processing 476 of set, immenstadt
# Processing 477 of set, oranjestad
# Processing 478 of set, rajur
# Processing 479 of set, cayenne
# Processing 480 of set, huarmey
# Processing 481 of set, sainte-suzanne
# Processing 482 of set, lebedinyy
# Processing 483 of set, razole
# Processing 484 of set, faya
# Processing 485 of set, mbengwi
# Processing 486 of set, whitehorse
# Processing 487 of set, rawson
# Processing 488 of set, camacha
# Processing 489 of set, camacupa
# Processing 490 of set, lake charles
# Processing 491 of set, powell
# Processing 492 of set, novyy urgal
# Processing 493 of set, wanning
# Processing 494 of set, port moresby
# Processing 495 of set, galiwinku
# Processing 496 of set, bur gabo
# Processing 497 of set, guerrero
# Processing 498 of set, cuamba
# Processing 499 of set, mulege
# Processing 500 of set, harrison
# Processing 501 of set, myaundzha
# Processing 502 of set, trairi
# Processing 503 of set, takab
# Processing 504 of set, red deer
# Processing 505 of set, reconquista
# Processing 506 of set, umzimvubu
# Processing 507 of set, rio grande
# Processing 508 of set, havre-saint-pierre
# Processing 509 of set, najran
# Processing 510 of set, letka
# Processing 511 of set, resistencia
# Processing 512 of set, walla walla
# Processing 513 of set, khonsa
# Processing 514 of set, guerrero negro
# Processing 515 of set, kargasok
# Processing 516 of set, kirakira
# Processing 517 of set, manggar
# Processing 518 of set, bandarbeyla
# Processing 519 of set, shubarshi
# Processing 520 of set, onega
# Processing 521 of set, dandong
# Processing 522 of set, ngunguru
# Processing 523 of set, louisbourg
# Processing 524 of set, eenhana
# Processing 525 of set, anar darreh
# Processing 526 of set, raudeberg
# Processing 527 of set, saldanha
# Processing 528 of set, aswan
# Processing 529 of set, inuvik
# Processing 530 of set, galich
# Processing 531 of set, nouadhibou
# Processing 532 of set, villafranca de los barros
# Processing 533 of set, puro
# Processing 534 of set, yeppoon
# Processing 535 of set, vestmanna
# Processing 536 of set, attawapiskat
# Processing 537 of set, robertsport
# Processing 538 of set, baruun-urt
# Processing 539 of set, lishu
# Processing 540 of set, gorno-chuyskiy
# Processing 541 of set, lipova
# Processing 542 of set, kipini
# Processing 543 of set, tessalit
# Processing 544 of set, kaka
# Processing 545 of set, ganta
# Processing 546 of set, le port
# Processing 547 of set, saint-leu
# Processing 548 of set, balakhta
# Processing 549 of set, zhezkazgan
# Processing 550 of set, namtsy
# Processing 551 of set, jalu
# Processing 552 of set, ancud
# Processing 553 of set, yulara
# Processing 554 of set, alofi
# Processing 555 of set, oistins
# Processing 556 of set, port-cartier
# Processing 557 of set, muriwai beach
# Processing 558 of set, zheleznodorozhnyy
# Processing 559 of set, stankov
# Processing 560 of set, ormara
# Processing 561 of set, yanam
# Processing 562 of set, maceio
# Processing 563 of set, tkvarcheli
# Processing 564 of set, sabak
# Processing 565 of set, gadarwara
# Processing 566 of set, bedesa
# Processing 567 of set, ciudad bolivar
# Processing 568 of set, buarcos
# Processing 569 of set, merrill
# Processing 570 of set, magdagachi
# Processing 571 of set, whyalla
# Processing 572 of set, quincy
# Processing 573 of set, hervey bay
# Processing 574 of set, gotsu
# Processing 575 of set, ventersburg
# Processing 576 of set, caravelas
# Processing 577 of set, bhadrak
# Processing 578 of set, hvide sande
# Processing 579 of set, fare
# Processing 580 of set, sataua
# Processing 581 of set, rafai
# Processing 582 of set, turayf
# Processing 583 of set, bartica
# Processing 584 of set, dubrovytsya
# Processing 585 of set, mae ramat
# Processing 586 of set, nurota
# Processing 587 of set, chokurdakh
# Processing 588 of set, baykalsk
# Processing 589 of set, yei
# Processing 590 of set, grevena
# Processing 591 of set, hami
# Processing 592 of set, isla mujeres
# Processing 593 of set, deputatskiy
# Processing 594 of set, balabac
# Processing 595 of set, goundi
# Processing 596 of set, rio gallegos
# Processing 597 of set, dzhusaly
# Processing 598 of set, tete
# Processing 599 of set, marsa matruh
# Processing 600 of set, brenham
# Processing 601 of set, yalchiki
# Processing 602 of set, mezhdurechensk
# Processing 603 of set, port augusta
# Processing 604 of set, schruns
# Processing 605 of set, juruti
# Processing 606 of set, dawlatabad
# Processing 607 of set, kuching
# Processing 608 of set, kasongo-lunda
# Processing 609 of set, mena
# Processing 610 of set, ituni
# Processing 611 of set, ouargaye
# Processing 612 of set, namibe
# Processing 613 of set, srandakan
# Processing 614 of set, uruzgan
# Processing 615 of set, kamenka
# Processing 616 of set, kumluca
# Processing 617 of set, coulihaut
# Processing 618 of set, saint-joseph
# Processing 619 of set, muroto
